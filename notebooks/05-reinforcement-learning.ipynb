# %%
# %matplotlib inline
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils.helpers import launch_env, wrap_env, view_results_ipython, change_exercise, seedall, force_done, evaluate_policy
from utils.helpers import SteeringToWheelVelWrapper, ResizeWrapper, ImgWrapper

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import matplotlib.pyplot as plt
# Out:
# INFO:aido-protocols:aido-protocols 5.0.5
# 08:00:59|zn|__init__.py:6|<module>(): zn 2.0.3
# 08:01:00|zj|__init__.py:5|<module>(): zj 2.0.4
# 08:01:00|gym-duckietown|__init__.py:10|<module>(): gym-duckietown 5.0.3
#
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-loop_pedestrians-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-small_loop_cw-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-loop_empty-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-loop_obstacles-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-zigzag_dists-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-straight_road-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-4way-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-small_loop-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-udem1-v0
# 08:01:00|gym-duckietown|__init__.py:24|reg_map_env(): Registering gym environment id: Duckietown-loop_dyn_duckiebots-v0
# 08:01:01|dt-world|__init__.py:12|<module>(): duckietown-world 1.0.30
# 08:01:01|dt-world|__init__.py:22|<module>(): contracts 1.8.12

# %% [markdown]
# # Reinforcement Learning Basics
#
# Reinforcement Learning, as we saw in lecture, is the idea of learning a _policy_ in order to maximize future (potentially discounted) rewards. Our policy, similar to the imitation learning network, maps raw image observations to wheel velocities, and at every timestep, receives a _reward_ from the environment.
#
# Rewards can be sparse (`1` if goal or task is completed, `0` otherwise) or dense; in general, dense rewards make it easier to learn policies, but as we'll see later in this exercise, defining the correct dense reward is an engineering challenge on its own.
#
# Today's reinforcement learning algorithms are often a mix between _value-based_ and _policy-gradient_ algorithms, instances of what is called an _actor-critic_ formulation. Actor-critic methods have had a lot of research done on them in recent years (especially within in the deep reinforcement learning era), and later in this exercise, we shall also rediscover the formulation's original problems and different methods currently used to stabilize learning.
#
# We begin by defining two networks, an `Actor` and `Critic`; in this exercise, we'll be using a deep RL algorithm titled _Deep Deterministic Policy Gradients_.

# %%
class Actor(nn.Module):
    def __init__(self, action_dim, max_action):
        super(Actor, self).__init__()
        
        # TODO: You'll need to change this!
        flat_size = 31968

        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

        self.conv1 = nn.Conv2d(3, 32, 8, stride=2)
        self.conv2 = nn.Conv2d(32, 32, 4, stride=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(32)

        self.dropout = nn.Dropout(.1)

        self.lin1 = nn.Linear(flat_size, 100)
        self.lin2 = nn.Linear(100, action_dim)

        self.max_action = max_action

    def forward(self, x):
        x = self.bn1(self.relu(self.conv1(x)))
        x = self.bn2(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)  # flatten
        x = self.dropout(x)
        x = self.relu(self.lin1(x))

        x = self.lin2(x)
        x = self.max_action * self.tanh(x)
        
        return x
    
class Critic(nn.Module):
    def __init__(self, action_dim, max_action):
        super(Critic, self).__init__()
        
        # TODO: You'll need to change this!
        flat_size = 31968

        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

        self.conv1 = nn.Conv2d(3, 32, 8, stride=2)
        self.conv2 = nn.Conv2d(32, 32, 4, stride=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(32)

        self.dropout = nn.Dropout(.1)

        self.lin1 = nn.Linear(flat_size + action_dim, 100)
        #self.lin2 = nn.Linear(100, action_dim)
        self.lin2 = nn.Linear(100, 1)
        #self.max_action = max_action

    def forward(self, obs, action):
        x = self.bn1(self.relu(self.conv1(obs)))
        x = self.bn2(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)  # flatten
        x = self.dropout(x)
        x = torch.cat([x, action], 1)
        x = self.relu(self.lin1(x))

        x = self.lin2(x)
        #x = self.max_action * self.tanh(x)
        
        return x

# %% [markdown]
# ## Reward Engineering
#
# In this part of the exercise, we will experiment with the reward formulation. Given the same model, we'll see how the effect of various reward functions changes the final policy trained.
#
# In the section below, we'll take a look at the reward function implemented in `gym-duckietown` with a slightly modified training loop. Traditionally, we `reset()` the environment to start an episode, and then `step()` the environment forward for a set amount of time, executing a new action. If this sounds a bit odd, especially for roboticists, you're right - in real robotics, most code runs asynchronously. As a result, although `gym-duckietown` runs locally by stopping the environment, the `AIDO` submissions will run asynchronously, executing the same action until a new one is received.

# %%
def updated_reward(env):
    # Compute the collision avoidance penalty
    pos, angle, speed = env.cur_pos, env.cur_angle, env.speed
    col_penalty = env.proximity_penalty2(pos, angle) # negative number
    print('col_penalty: %.4f'% col_penalty)
    # Get the position relative to the right lane tangent
    try:
        lp = env.get_lane_pos2(pos, angle)
    except NotInLane:
        reward = 40 * col_penalty
    else:
        # Compute the reward
        reward = (
                1 * speed * lp.dot_dir +
                1 * np.abs(lp.dist) +
                1 * col_penalty
        )
    return reward

# %%
nepisodes = 3

# %%
local_env = launch_env()
local_env = wrap_env(local_env)
local_env = ResizeWrapper(local_env)
local_env = ImgWrapper(local_env)

policy = Actor(2, 1.0)

for _ in range(nepisodes):
    done = False
    obs = local_env.reset() # (3,160,120)
    
    while not done:
        obs, r, done, info = local_env.step(np.random.random(2))
        new_r = updated_reward(local_env)
        print('Reward: %.4f --- Updated Reward: %.4f' % (r, new_r))
# Out:
# 08:01:02|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 08:01:02|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 08:01:02|gym-duckietown|simulator.py:550|_load_map(): loading map file "/duckietown/simulation/gym_duckietown/maps/loop_empty.yaml"
# 08:01:02|gym-duckietown|objmesh.py:50|__init__(): loading mesh "duckiebot.obj"
# 08:01:02|gym-duckietown|objmesh.py:238|_load_mtl(): loading materials from "/duckietown/simulation/gym_duckietown/meshes/duckiebot.mtl"
# 08:01:03|gym-duckietown|objmesh.py:50|__init__(): loading mesh "duckie.obj"
# 08:01:03|gym-duckietown|graphics.py:60|load_texture(): loading texture "duckie.png"
# 08:01:03|gym-duckietown|objmesh.py:50|__init__(): loading mesh "cone.obj"
# 08:01:03|gym-duckietown|graphics.py:60|load_texture(): loading texture "cone.png"
# 08:01:04|gym-duckietown|graphics.py:60|load_texture(): loading texture "floor_1.png"
# 08:01:04|gym-duckietown|graphics.py:60|load_texture(): loading texture "curve_left_1.png"
# 08:01:04|gym-duckietown|graphics.py:60|load_texture(): loading texture "straight_1.png"
# 08:01:04|gym-duckietown|graphics.py:60|load_texture(): loading texture "curve_right_1.png"
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.13719561 0.         1.88880899] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.0873995 0.        1.9726338]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.03760339 0.         2.0564586 ]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.13719561 0.         1.88880899]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.98680973 0.         1.91287847]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.10908822 0.         2.30642426] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.0793971  0.         2.21355507]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.10908822 0.         2.30642426]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.04970598 0.         2.12068587]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.96795406 0.         2.24918441]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.47880119 0.         2.23809688] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.54467288 0.         2.16621385]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.47880119 0.         2.23809688]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.61054457 0.         2.09433082]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.45841324 0.         2.08716782]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.11902599 0.         2.07053136] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.05777514 0.         2.14639032]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.11902599 0.         2.07053136]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.99652428 0.         2.22224929]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.14880589 0.         2.21989135]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.11072664 0.         2.23740683] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.06163269 0.         2.15316887]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.11072664 0.         2.23740683]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.01253874 0.         2.0689309 ]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.96054713 0.         2.2120816 ]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.09719614 0.         2.20147659] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.00591875 0.         2.23575032]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.09719614 0.         2.20147659]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.91464137 0.         2.27002405]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.04704723 0.         2.34528318]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.48173779 0.         2.07668522] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.59826268 0.         2.08721855]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.5894849  0.         2.18432262]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.60704045 0.         1.99011448]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.48173779 0.         2.07668522]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.48172154 0.         1.84866924] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.57292165 0.         1.88314807]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.48172154 0.         1.84866924]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.66412176 0.         1.91762689]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.61429624 0.         1.77370793]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.50690495 0.         2.23654429] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.6172817  0.         2.19773742]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.64962075 0.         2.28971804]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.58494264 0.         2.10575679]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.50690495 0.         2.23654429]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.11050548 0.         2.28364106] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.00116556 0.         2.24200236]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.03586448 0.         2.15088576]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.96646664 0.         2.33311896]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.11050548 0.         2.28364106]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.50186974 0.         2.10261411] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.5769519  0.         2.04041348]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.50186974 0.         2.10261411]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.65203407 0.         1.97821284]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.50231114 0.         1.95031488]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.47260658 0.         1.77460142] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.58708306 0.         1.75043253]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.6072238 0.        1.8458296]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.56694232 0.         1.65503546]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.47260658 0.         1.77460142]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.09934153 0.         1.85301864] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.02300463 0.         1.79236447]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.94666773 0.         1.7317103 ]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.09934153 0.         1.85301864]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.09578963 0.         1.70076019]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.17105167 0.         1.80077003] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.09036721 0.         1.85550821]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.00968276 0.         1.9102464 ]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.17105167 0.         1.80077003]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.02468139 0.         1.75868687]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.49620504 0.         2.20742184] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.57500004 0.         2.14999713]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.49620504 0.         2.20742184]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.65379505 0.         2.09257242]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.50609039 0.         2.05544313]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.12972415 0.         2.27350789] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.022444   0.         2.32019802]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.98353555 0.         2.23079789]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.06135244 0.         2.40959815]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.12972415 0.         2.27350789]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.14789125 0.         1.98595245] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.05139065 0.         1.99987665]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.95489004 0.         2.01380085]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.14789125 0.         1.98595245]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.0346816  0.         1.88407592]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.50005426 0.         1.72007355] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.58276167 0.         1.80282911]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.5137987  0.         1.87175196]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.65172464 0.         1.73390626]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.50005426 0.         1.72007355]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.49842474 0.         1.9311518 ] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.60040652 0.         1.87380448]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.64819596 0.         1.9587893 ]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.55261709 0.         1.78881966]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.49842474 0.         1.9311518 ]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.1279325  0.         2.40562151] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.04505092 0.         2.35427082]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.96216934 0.         2.30292013]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [4.1279325  0.         2.40562151]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.10667175 0.         2.25481292]
# 08:01:04|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.4840149 0.        2.2828545] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:04|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:04|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:04|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.57730109 0.         2.31120829]
# 08:01:04|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.4840149 0.        2.2828545]
# 08:01:04|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.67058727 0.         2.33956208]
# 08:01:04|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.61132563 0.         2.19926486]
# 08:01:04|gym-duckietown|simulator.py:531|reset(): Starting at [3.89201099 0.         2.08907339] 1.6292900738092628
# 08:01:04|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.89201099 0.         2.08907339] angle 1.6292900738092628
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 08:01:10|gym-duckietown|simulator.py:1107|_drivable_pos(): [2.33703727 0.         2.57700384] corresponds to tile at (3, 4) which is not drivable: {'coords': (3, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:10|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:10|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:10|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [2.33703727 0.         2.57700384]
# 08:01:10|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [2.24568806 0.         2.542922  ]
# 08:01:10|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [2.42838647 0.         2.61108568]
# 08:01:10|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [2.37793548 0.         2.46738479]
# 08:01:10|gym-duckietown|simulator.py:1107|_drivable_pos(): [2.28873639 0.         2.68406941] corresponds to tile at (3, 4) which is not drivable: {'coords': (3, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:10|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:10|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:10|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [2.38071712 0.         2.71640816]
# 08:01:10|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [2.28873639 0.         2.68406941]
# 08:01:10|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [2.47269785 0.         2.74874692]
# 08:01:10|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [2.41952363 0.         2.60603129]
# 08:01:10|gym-duckietown|simulator.py:531|reset(): Starting at [2.64153703 0.         2.88468928] 4.836049502872963
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.64153703 0.         2.88468928] angle 4.836049502872963
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.64153703 0.         2.88468928] angle 4.836049502872963
# action_dim:2
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6415370304316736, 0, 2.884689280745409] angle -1.4471358043066236
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.641726955682716, 0, 2.886196174167221] angle -1.4437038209104198
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.641726955682716, 0, 2.886196174167221] angle -1.4437038209104198
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.642100482641576, 0, 2.889139998087954] angle -1.4454678019834488
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.642100482641576, 0, 2.889139998087954] angle -1.4454678019834488
# col_penalty: 0.0000
# Reward: -0.1101 --- Updated Reward: 0.1310
# col_penalty: 0.0000
# Reward: -0.1101 --- Updated Reward: 0.1310
# col_penalty: 0.0000
# Reward: -0.1101 --- Updated Reward: 0.1310
# col_penalty: 0.0000
# Reward: -0.1101 --- Updated Reward: 0.1310
# col_penalty: 0.0000
# Reward: -0.1099 --- Updated Reward: 0.1310
# col_penalty: 0.0000
# Reward: -0.1099 --- Updated Reward: 0.1309
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.642436546500211, 0, 2.8918369527691348] angle -1.4481855750711006
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.642436546500211, 0, 2.8918369527691348] angle -1.4481855750711006
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.642928129122019, 0, 2.8957363265619307] angle -1.442596062629904
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.642928129122019, 0, 2.8957363265619307] angle -1.442596062629904
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.643394135332763, 0, 2.8993114428358515] angle -1.4397638554204282
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.643394135332763, 0, 2.8993114428358515] angle -1.4397638554204282
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6439806884796715, 0, 2.9038531648991333] angle -1.444955161761176
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6439806884796715, 0, 2.9038531648991333] angle -1.444955161761176
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.644717095523942, 0, 2.9097645868721305] angle -1.4487672507500589
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.644717095523942, 0, 2.9097645868721305] angle -1.4487672507500589
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6455727552388018, 0, 2.916818050579724] angle -1.451384018033992
# col_penalty: 0.0000
# Reward: -0.1095 --- Updated Reward: 0.1308
# col_penalty: 0.0000
# Reward: -0.1084 --- Updated Reward: 0.1307
# col_penalty: 0.0000
# Reward: -0.1068 --- Updated Reward: 0.1305
# col_penalty: 0.0000
# Reward: -0.1042 --- Updated Reward: 0.1302
# col_penalty: 0.0000
# Reward: -0.1005 --- Updated Reward: 0.1297
# 08:01:10|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6455727552388018, 0, 2.916818050579724] angle -1.451384018033992
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.646621659935202, 0, 2.9256900271537445] angle -1.4548477266669788
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.646621659935202, 0, 2.9256900271537445] angle -1.4548477266669788
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6476805076740146, 0, 2.93516540369167] angle -1.4641737127255812
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6476805076740146, 0, 2.93516540369167] angle -1.4641737127255812
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6487684016785398, 0, 2.9453738572494053] angle -1.465084422351721
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6487684016785398, 0, 2.9453738572494053] angle -1.465084422351721
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.649748366086213, 0, 2.954879861706468] angle -1.4710560016986243
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.649748366086213, 0, 2.954879861706468] angle -1.4710560016986243
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6506380349305694, 0, 2.9641151820519793] angle -1.4784627527826808
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6506380349305694, 0, 2.9641151820519793] angle -1.4784627527826808
# col_penalty: 0.0000
# Reward: -0.0956 --- Updated Reward: 0.1292
# col_penalty: 0.0000
# Reward: -0.1196 --- Updated Reward: 0.1311
# col_penalty: 0.0000
# Reward: -0.1328 --- Updated Reward: 0.1323
# col_penalty: 0.0000
# Reward: -0.1503 --- Updated Reward: 0.1337
# col_penalty: 0.0000
# Reward: -0.1691 --- Updated Reward: 0.1352
# col_penalty: 0.0000
# Reward: -0.1872 --- Updated Reward: 0.1368
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6515511766993254, 0, 2.97378632788835] angle -1.4748496992425482
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6515511766993254, 0, 2.97378632788835] angle -1.4748496992425482
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.652466128364776, 0, 2.9830023708802633] angle -1.468835164344013
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.652466128364776, 0, 2.9830023708802633] angle -1.468835164344013
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.653406150425831, 0, 2.991836502765225] angle -1.4607393456015287
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.653406150425831, 0, 2.991836502765225] angle -1.4607393456015287
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.654529477935169, 0, 3.001616725081065] angle -1.4521414221470244
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.654529477935169, 0, 3.001616725081065] angle -1.4521414221470244
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6557558436029436, 0, 3.011649272943463] angle -1.4461807028174511
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6557558436029436, 0, 3.011649272943463] angle -1.4461807028174511
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6570368838313665, 0, 3.0214670123513514] angle -1.435913630412115
# col_penalty: 0.0000
# Reward: -0.2121 --- Updated Reward: 0.1387
# col_penalty: 0.0000
# Reward: -0.2404 --- Updated Reward: 0.1407
# col_penalty: 0.0000
# Reward: -0.2708 --- Updated Reward: 0.1429
# col_penalty: 0.0000
# Reward: -0.3099 --- Updated Reward: 0.1457
# col_penalty: 0.0000
# Reward: -0.3536 --- Updated Reward: 0.1488
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6570368838313665, 0, 3.0214670123513514] angle -1.435913630412115
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6583064643855203, 0, 3.030925750384227] angle -1.4388278348898837
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6583064643855203, 0, 3.030925750384227] angle -1.4388278348898837
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.659671831267765, 0, 3.0410095646761266] angle -1.4335981345427735
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.659671831267765, 0, 3.0410095646761266] angle -1.4335981345427735
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.661074695654875, 0, 3.0512049073118916] angle -1.434514749356536
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.661074695654875, 0, 3.0512049073118916] angle -1.434514749356536
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6624434124444925, 0, 3.0614324335646836] angle -1.441005269687419
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6624434124444925, 0, 3.0614324335646836] angle -1.441005269687419
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.663913500339597, 0, 3.072984031336988] angle -1.447422800640911
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.663913500339597, 0, 3.072984031336988] angle -1.447422800640911
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.665274696066976, 0, 3.084068727992307] angle -1.449794230773679
# col_penalty: 0.0000
# Reward: -0.4034 --- Updated Reward: 0.1522
# col_penalty: 0.0000
# Reward: -0.4478 --- Updated Reward: 0.1558
# col_penalty: 0.0000
# Reward: -0.5048 --- Updated Reward: 0.1598
# col_penalty: 0.0000
# Reward: -0.5667 --- Updated Reward: 0.1641
# col_penalty: 0.0000
# Reward: -0.6195 --- Updated Reward: 0.1687
# col_penalty: 0.0000
# Reward: -0.6844 --- Updated Reward: 0.1741
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.665274696066976, 0, 3.084068727992307] angle -1.449794230773679
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6666808806334306, 0, 3.095912805174821] angle -1.4554553322307746
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6666808806334306, 0, 3.095912805174821] angle -1.4554553322307746
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.66798017974013, 0, 3.107084352768295] angle -1.454569083937558
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.66798017974013, 0, 3.107084352768295] angle -1.454569083937558
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.669285876230797, 0, 3.11853170343478] angle -1.459883161740893
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.669285876230797, 0, 3.11853170343478] angle -1.459883161740893
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6703673173012463, 0, 3.1283719237359677] angle -1.462787876803966
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6703673173012463, 0, 3.1283719237359677] angle -1.462787876803966
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6715067548371123, 0, 3.1391223938177446] angle -1.4676141358116954
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6715067548371123, 0, 3.1391223938177446] angle -1.4676141358116954
# col_penalty: 0.0000
# Reward: -0.7568 --- Updated Reward: 0.1796
# col_penalty: 0.0000
# Reward: -0.8307 --- Updated Reward: 0.1857
# col_penalty: 0.0000
# Reward: -0.9089 --- Updated Reward: 0.1917
# col_penalty: 0.0000
# Reward: -0.9880 --- Updated Reward: 0.1980
# col_penalty: 0.0000
# Reward: -1.0624 --- Updated Reward: 0.2037
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.672651143315984, 0, 3.1498010015134748] angle -1.4604605221892053
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.672651143315984, 0, 3.1498010015134748] angle -1.4604605221892053
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.673745918848455, 0, 3.1599753101754535] angle -1.4667530497132117
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.673745918848455, 0, 3.1599753101754535] angle -1.4667530497132117
# 08:01:11|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6747201777796894, 0, 3.1702371904168016] angle -1.485527807798554
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6747201777796894, 0, 3.1702371904168016] angle -1.485527807798554
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6754121982842136, 0, 3.179391867909046] angle -1.5051677983994987
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6754121982842136, 0, 3.179391867909046] angle -1.5051677983994987
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6758694358750463, 0, 3.1880400700179257] angle -1.5307815652279386
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6758694358750463, 0, 3.1880400700179257] angle -1.5307815652279386
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6760916423883816, 0, 3.195630631705036] angle -1.552279696267345
# col_penalty: 0.0000
# Reward: -1.1382 --- Updated Reward: 0.2101
# col_penalty: 0.0000
# Reward: -1.2252 --- Updated Reward: 0.2166
# col_penalty: 0.0000
# Reward: -1.3016 --- Updated Reward: 0.2231
# col_penalty: 0.0000
# Reward: -1.3701 --- Updated Reward: 0.2296
# col_penalty: 0.0000
# Reward: -1.4311 --- Updated Reward: 0.2355
# col_penalty: 0.0000
# Reward: -1.4782 --- Updated Reward: 0.2410
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6760916423883816, 0, 3.195630631705036] angle -1.552279696267345
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.676150029747086, 0, 3.2024977774180687] angle -1.5723085265903658
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.676150029747086, 0, 3.2024977774180687] angle -1.5723085265903658
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.676095806422556, 0, 3.20945972618936] angle -1.584860865621025
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.676095806422556, 0, 3.20945972618936] angle -1.584860865621025
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.675991474143575, 0, 3.217232037187473] angle -1.5835773460138034
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.675991474143575, 0, 3.217232037187473] angle -1.5835773460138034
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6758595044351563, 0, 3.2251742838360418] angle -1.5912445865914149
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6758595044351563, 0, 3.2251742838360418] angle -1.5912445865914149
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6756686154234735, 0, 3.233277771952065] angle -1.5974521565810982
# col_penalty: 0.0000
# Reward: -1.5214 --- Updated Reward: 0.2458
# col_penalty: 0.0000
# Reward: -1.5609 --- Updated Reward: 0.2501
# col_penalty: 0.0000
# Reward: -1.6066 --- Updated Reward: 0.2544
# col_penalty: 0.0000
# Reward: -1.6683 --- Updated Reward: 0.2593
# col_penalty: 0.0000
# Reward: -1.7253 --- Updated Reward: 0.2644
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6756686154234735, 0, 3.233277771952065] angle -1.5974521565810982
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6754312942318785, 0, 3.24093723352493] angle -1.606088791765442
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6754312942318785, 0, 3.24093723352493] angle -1.606088791765442
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.675073894448252, 0, 3.2488101930240205] angle -1.626233295611243
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.675073894448252, 0, 3.2488101930240205] angle -1.626233295611243
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6745332174755934, 0, 3.2574432167203744] angle -1.6404538177671713
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6745332174755934, 0, 3.2574432167203744] angle -1.6404538177671713
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6737995772627903, 0, 3.266526490724429] angle -1.6623254573610882
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6737995772627903, 0, 3.266526490724429] angle -1.6623254573610882
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6728728446727623, 0, 3.2754781967124997] angle -1.6855838332890913
# col_penalty: 0.0000
# Reward: -1.7851 --- Updated Reward: 0.2697
# col_penalty: 0.0000
# Reward: -1.8407 --- Updated Reward: 0.2747
# col_penalty: 0.0000
# Reward: -1.8886 --- Updated Reward: 0.2798
# col_penalty: 0.0000
# Reward: -1.9462 --- Updated Reward: 0.2855
# col_penalty: 0.0000
# Reward: -2.0007 --- Updated Reward: 0.2914
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6728728446727623, 0, 3.2754781967124997] angle -1.6855838332890913
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.671741205670136, 0, 3.284949419321653] angle -1.6938449797817468
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.671741205670136, 0, 3.284949419321653] angle -1.6938449797817468
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6706216283896933, 0, 3.293751419624245] angle -1.7007804824221244
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6706216283896933, 0, 3.293751419624245] angle -1.7007804824221244
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6693549715984437, 0, 3.303360579073518] angle -1.702936224134159
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6693549715984437, 0, 3.303360579073518] angle -1.702936224134159
# col_penalty: 0.0000
# Reward: -2.0530 --- Updated Reward: 0.2972
# col_penalty: 0.0000
# Reward: -2.1205 --- Updated Reward: 0.3034
# col_penalty: 0.0000
# Reward: -2.1853 --- Updated Reward: 0.3092
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.668141944571026, 0, 3.3127992849846497] angle -1.694287690537041
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.668141944571026, 0, 3.3127992849846497] angle -1.694287690537041
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6671258427700026, 0, 3.3214985773486263] angle -1.6798568447030904
# 08:01:12|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6671258427700026, 0, 3.3214985773486263] angle -1.6798568447030904
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6662165972464416, 0, 3.330806404155929] angle -1.6564901392485643
# col_penalty: 0.0000
# Reward: -2.2664 --- Updated Reward: 0.3156
# col_penalty: 0.0000
# Reward: -2.3505 --- Updated Reward: 0.3221
# col_penalty: 0.0000
# Reward: -2.4301 --- Updated Reward: 0.3282
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6662165972464416, 0, 3.330806404155929] angle -1.6564901392485643
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.665488588953069, 0, 3.340106314048908] angle -1.6413463230476901
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.665488588953069, 0, 3.340106314048908] angle -1.6413463230476901
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.664925949151894, 0, 3.348578471787088] angle -1.6328724819277762
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.664925949151894, 0, 3.348578471787088] angle -1.6328724819277762
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.664478349624813, 0, 3.356535525833448] angle -1.6211055617872634
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.664478349624813, 0, 3.356535525833448] angle -1.6211055617872634
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6640885964873195, 0, 3.3651164605380166] angle -1.6112663496037336
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6640885964873195, 0, 3.3651164605380166] angle -1.6112663496037336
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.66379532676403, 0, 3.373650860027999] angle -1.5990257763156408
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.66379532676403, 0, 3.373650860027999] angle -1.5990257763156408
# col_penalty: 0.0000
# Reward: -2.5308 --- Updated Reward: 0.3349
# col_penalty: 0.0000
# Reward: -2.6272 --- Updated Reward: 0.3419
# col_penalty: 0.0000
# Reward: -2.7133 --- Updated Reward: 0.3483
# col_penalty: 0.0000
# Reward: -2.7929 --- Updated Reward: 0.3545
# col_penalty: 0.0000
# Reward: -2.8768 --- Updated Reward: 0.3612
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6636163102483437, 0, 3.3821464532883665] angle -1.5847040234035932
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6636163102483437, 0, 3.3821464532883665] angle -1.5847040234035932
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6635338141065508, 0, 3.3912894808325604] angle -1.574933835187407
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6635338141065508, 0, 3.3912894808325604] angle -1.574933835187407
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6635597712793655, 0, 3.3999873785794574] angle -1.5606902277125956
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6635597712793655, 0, 3.3999873785794574] angle -1.5606902277125956
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6637746152872936, 0, 3.4090440518265384] angle -1.533466968041948
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6637746152872936, 0, 3.4090440518265384] angle -1.533466968041948
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6642005273332585, 0, 3.4187922231707293] angle -1.5207982624600396
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6642005273332585, 0, 3.4187922231707293] angle -1.5207982624600396
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.664680923355882, 0, 3.428189526278949] angle -1.518642061656242
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.664680923355882, 0, 3.428189526278949] angle -1.518642061656242
# col_penalty: 0.0000
# Reward: -2.9713 --- Updated Reward: 0.3680
# col_penalty: 0.0000
# Reward: -3.0617 --- Updated Reward: 0.3749
# col_penalty: 0.0000
# Reward: -3.1542 --- Updated Reward: 0.3825
# col_penalty: 0.0000
# Reward: -3.2564 --- Updated Reward: 0.3898
# col_penalty: 0.0000
# Reward: -3.3693 --- Updated Reward: 0.3975
# col_penalty: 0.0000
# Reward: -3.4750 --- Updated Reward: 0.4060
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6651611866019924, 0, 3.4370461766652443] angle -1.5146041364356633
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.6651611866019924, 0, 3.4370461766652443] angle -1.5146041364356633
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.665611483397785, 0, 3.445340617074881] angle -1.5185170185396188
# 08:01:13|gym-duckietown|simulator.py:1107|_drivable_pos(): [2.66906035 0.         3.51125044] corresponds to tile at (4, 6) which is not drivable: {'coords': (4, 6), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:13|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:13|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.0
# 08:01:13|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [2.66435735 0.         3.42137341]
# 08:01:13|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [2.73925488 0.         3.41745424]
# 08:01:13|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [2.58945982 0.         3.42529257]
# 08:01:13|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [2.66906035 0.         3.51125044]
# 08:01:13|gym-duckietown|simulator.py:1376|_compute_done_reward(): Stopping the simulator because we are at an invalid pose.
# 08:01:13|gym-duckietown|simulator.py:1435|_render_img(): Pos: [2.665611483397785, 0, 3.445340617074881] angle -1.5185170185396188
# 08:01:13|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.18711159 0.         1.2525156 ] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:13|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:13|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:13|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.15771193 0.         1.13926959]
# 08:01:13|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.25208361 0.         1.11476987]
# 08:01:13|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.06334025 0.         1.1637693 ]
# 08:01:13|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [3.18711159 0.         1.2525156 ]
# 08:01:13|gym-duckietown|simulator.py:1107|_drivable_pos(): [3.41116269 0.         1.23946167] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:13|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:13|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.3
# 08:01:13|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [3.35729556 0.         1.15819308]
# 08:01:13|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [3.30342844 0.         1.0769245 ]
# 08:01:13|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.41116269 0.         1.23946167]
# ...
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.7860014989739246, 0, 2.133391573876153] angle -1.5352197888322776
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.7863865126126828, 0, 2.141676761036926] angle -1.5134994395065342
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.787007850536056, 0, 2.150187572370154] angle -1.4823403499892513
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.7879431896651345, 0, 2.1591762015099887] angle -1.4518825467095948
# col_penalty: 0.0000
# Reward: 0.1994 --- Updated Reward: 0.1000
# col_penalty: 0.0000
# Reward: 0.1994 --- Updated Reward: 0.1000
# col_penalty: 0.0000
# Reward: 0.1994 --- Updated Reward: 0.1000
# col_penalty: 0.0000
# Reward: 0.1994 --- Updated Reward: 0.1000
# col_penalty: 0.0000
# Reward: 0.1996 --- Updated Reward: 0.1000
# col_penalty: 0.0000
# Reward: 0.1996 --- Updated Reward: 0.1000
# col_penalty: 0.0000
# Reward: 0.1995 --- Updated Reward: 0.1001
# col_penalty: 0.0000
# Reward: 0.1987 --- Updated Reward: 0.1001
# col_penalty: 0.0000
# Reward: 0.1970 --- Updated Reward: 0.1003
# col_penalty: 0.0000
# Reward: 0.1942 --- Updated Reward: 0.1005
# col_penalty: 0.0000
# Reward: 0.1892 --- Updated Reward: 0.1009
# col_penalty: 0.0000
# Reward: 0.1802 --- Updated Reward: 0.1015
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.789240799956674, 0, 2.169072884391931] angle -1.4289661386964367
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.7908609539079796, 0, 2.179453444255895] angle -1.4029731809283048
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.7929235346414063, 0, 2.1909114383466948] angle -1.3824096222396929
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.795094635220923, 0, 2.2020132133828962] angle -1.3729311191966143
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.7970705750631994, 0, 2.211685441529286] angle -1.3656271916933436
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.799364769145895, 0, 2.2226327406682866] angle -1.3628103154019713
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8018938909107227, 0, 2.23464882078424] angle -1.3638822168275773
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8040045037605013, 0, 2.2447205935533074] angle -1.3645742520004218
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8060433071795665, 0, 2.2543841848204584] angle -1.361161342982673
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8082858205442274, 0, 2.264876395840323] angle -1.3593050105848976
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8103321783721156, 0, 2.2744105219917605] angle -1.359432989309169
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.812114801489746, 0, 2.282667558165233] angle -1.3569036213534986
# col_penalty: 0.0000
# Reward: 0.1671 --- Updated Reward: 0.1024
# col_penalty: 0.0000
# Reward: 0.1505 --- Updated Reward: 0.1037
# col_penalty: 0.0000
# Reward: 0.1295 --- Updated Reward: 0.1054
# col_penalty: 0.0000
# Reward: 0.1045 --- Updated Reward: 0.1074
# col_penalty: 0.0000
# Reward: 0.0806 --- Updated Reward: 0.1096
# col_penalty: 0.0000
# Reward: 0.0591 --- Updated Reward: 0.1116
# col_penalty: 0.0000
# Reward: 0.0355 --- Updated Reward: 0.1139
# col_penalty: 0.0000
# Reward: 0.0105 --- Updated Reward: 0.1164
# col_penalty: 0.0000
# Reward: -0.0105 --- Updated Reward: 0.1185
# col_penalty: 0.0000
# Reward: -0.0317 --- Updated Reward: 0.1205
# col_penalty: 0.0000
# Reward: -0.0546 --- Updated Reward: 0.1228
# col_penalty: 0.0000
# Reward: -0.0750 --- Updated Reward: 0.1248
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.814151302726044, 0, 2.2918961376812166] angle -1.3503041415155757
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8161954496374237, 0, 2.3009928775194854] angle -1.3492078416357214
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8181720793608216, 0, 2.3100455866176395] angle -1.3624391235484998
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8201196204812122, 0, 2.3191617003903504] angle -1.3582070932837773
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.821870716881784, 0, 2.327291364968686] angle -1.3590764899239884
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.823896613398341, 0, 2.336778711611224] angle -1.361762013997794
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.826180360051517, 0, 2.347534408941126] angle -1.3613870541969963
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8286258671489493, 0, 2.3589854112594413] angle -1.3594016611261268
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.831067814019459, 0, 2.370574096969764] angle -1.3668310929260807
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8334401106485942, 0, 2.3819806319709835] angle -1.3646539030445344
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8357498334748303, 0, 2.392725748137858] angle -1.3534713196879806
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.838335393624114, 0, 2.404323388657032] angle -1.349418579130718
# col_penalty: 0.0000
# Reward: -0.0935 --- Updated Reward: 0.1266
# col_penalty: 0.0000
# Reward: -0.1156 --- Updated Reward: 0.1287
# col_penalty: 0.0000
# Reward: -0.1363 --- Updated Reward: 0.1307
# col_penalty: 0.0000
# Reward: -0.1527 --- Updated Reward: 0.1327
# col_penalty: 0.0000
# Reward: -0.1732 --- Updated Reward: 0.1346
# col_penalty: 0.0000
# Reward: -0.1905 --- Updated Reward: 0.1364
# col_penalty: 0.0000
# Reward: -0.2101 --- Updated Reward: 0.1384
# col_penalty: 0.0000
# Reward: -0.2372 --- Updated Reward: 0.1407
# col_penalty: 0.0000
# Reward: -0.2723 --- Updated Reward: 0.1435
# col_penalty: 0.0000
# Reward: -0.3098 --- Updated Reward: 0.1465
# col_penalty: 0.0000
# Reward: -0.3508 --- Updated Reward: 0.1498
# col_penalty: 0.0000
# Reward: -0.3979 --- Updated Reward: 0.1532
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.840954930622251, 0, 2.415881180946249] angle -1.3464113422743218
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8436110869905433, 0, 2.427223511971797] angle -1.3351102922408955
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8464440593371587, 0, 2.4385221963911716] angle -1.315142293266352
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.849722887800085, 0, 2.4505353736953968] angle -1.2935577439168153
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8532236154128987, 0, 2.462628170228935] angle -1.2844635167164729
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.856290155228373, 0, 2.472895000730829] angle -1.2766307761596034
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8595411280790866, 0, 2.4832402768120962] angle -1.2560104253752518
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.862788373802865, 0, 2.493133170013662] angle -1.2512626362258155
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8659906956461474, 0, 2.502759906266264] angle -1.2480613998911692
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.868833136091552, 0, 2.511172699300629] angle -1.2418731417507507
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.872321089293051, 0, 2.5213052911423017] angle -1.2366669740096412
# col_penalty: 0.0000
# Reward: -0.4523 --- Updated Reward: 0.1573
# col_penalty: 0.0000
# Reward: -0.5091 --- Updated Reward: 0.1617
# col_penalty: 0.0000
# Reward: -0.5772 --- Updated Reward: 0.1664
# col_penalty: 0.0000
# Reward: -0.6543 --- Updated Reward: 0.1716
# col_penalty: 0.0000
# Reward: -0.7444 --- Updated Reward: 0.1776
# col_penalty: 0.0000
# Reward: -0.8351 --- Updated Reward: 0.1843
# col_penalty: 0.0000
# Reward: -0.9243 --- Updated Reward: 0.1902
# col_penalty: 0.0000
# Reward: -1.0074 --- Updated Reward: 0.1966
# col_penalty: 0.0000
# Reward: -1.0937 --- Updated Reward: 0.2030
# col_penalty: 0.0000
# Reward: -1.1755 --- Updated Reward: 0.2094
# col_penalty: 0.0000
# Reward: -1.2540 --- Updated Reward: 0.2152
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8759182092207234, 0, 2.5313983103880116] angle -1.2202014051923264
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.87987488551801, 0, 2.541932542604143] angle -1.202794953100895
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8839669867459428, 0, 2.552308738140466] angle -1.1875038094984305
# 08:01:17|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8879073926974828, 0, 2.561990926806659] angle -1.1810797193671712
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8919951953821426, 0, 2.5718594494279694] angle -1.1750928408626466
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.8963890117363027, 0, 2.5823894529458356] angle -1.1758958096718644
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9010633484492345, 0, 2.593587786823787] angle -1.1748420837382645
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9057888658395403, 0, 2.604971328539206] angle -1.179808281210902
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9102864798294243, 0, 2.6157563516958824] angle -1.1715931856179336
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9151286659755278, 0, 2.6271463681119664] angle -1.1660456247489879
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9198793548862603, 0, 2.6383547255612214] angle -1.1737506363468049
# col_penalty: 0.0000
# Reward: -1.3466 --- Updated Reward: 0.2224
# col_penalty: 0.0000
# Reward: -1.4521 --- Updated Reward: 0.2299
# col_penalty: 0.0000
# Reward: -1.5665 --- Updated Reward: 0.2380
# col_penalty: 0.0000
# Reward: -1.6825 --- Updated Reward: 0.2463
# col_penalty: 0.0000
# Reward: -1.7815 --- Updated Reward: 0.2543
# col_penalty: 0.0000
# Reward: -1.8839 --- Updated Reward: 0.2627
# col_penalty: 0.0000
# Reward: -1.9943 --- Updated Reward: 0.2717
# col_penalty: 0.0000
# Reward: -2.1069 --- Updated Reward: 0.2815
# col_penalty: 0.0000
# Reward: -2.2238 --- Updated Reward: 0.2915
# col_penalty: 0.0000
# Reward: -2.3428 --- Updated Reward: 0.3011
# col_penalty: 0.0000
# Reward: -2.4668 --- Updated Reward: 0.3114
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9241183645204005, 0, 2.648464643147203] angle -1.173789662389367
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9283797189076015, 0, 2.6584131766894235] angle -1.1584105657612678
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9328111678648145, 0, 2.668159026795947] angle -1.1296690961519282
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.93747572044871, 0, 2.677751573481909] angle -1.1067193008745058
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9421048885061603, 0, 2.6867344757813636] angle -1.0831992449540357
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9462601193711744, 0, 2.694366172628333] angle -1.061217994527029
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.950632857615089, 0, 2.7020060535177817] angle -1.040683415263868
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9555955732987305, 0, 2.7103455000694714] angle -1.0273074550240315
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9608731357137152, 0, 2.7190332329327305] angle -1.0224928375527713
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.966580294038571, 0, 2.7282528804104227] angle -1.0105228541081699
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9723551613398365, 0, 2.737398438681148] angle -1.004636569878066
# col_penalty: 0.0000
# Reward: -2.5768 --- Updated Reward: 0.3217
# col_penalty: 0.0000
# Reward: -2.6775 --- Updated Reward: 0.3310
# col_penalty: 0.0000
# Reward: -2.8019 --- Updated Reward: 0.3402
# col_penalty: 0.0000
# Reward: -2.9337 --- Updated Reward: 0.3496
# col_penalty: 0.0000
# Reward: -3.0698 --- Updated Reward: 0.3591
# col_penalty: 0.0000
# Reward: -3.1954 --- Updated Reward: 0.3683
# col_penalty: 0.0000
# Reward: -3.3080 --- Updated Reward: 0.3763
# col_penalty: 0.0000
# Reward: -3.4127 --- Updated Reward: 0.3844
# col_penalty: 0.0000
# Reward: -3.5274 --- Updated Reward: 0.3936
# col_penalty: 0.0000
# Reward: -3.6375 --- Updated Reward: 0.4031
# col_penalty: 0.0000
# Reward: -3.7627 --- Updated Reward: 0.4134
# col_penalty: 0.0000
# Reward: -3.8813 --- Updated Reward: 0.4237
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.978072043363679, 0, 2.7463494904124657] angle -1.000199838735178
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.9843378597540577, 0, 2.756025646299708] angle -0.9920877183836424
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.990787493978155, 0, 2.7659281516630774] angle -0.9949090241903511
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [3.996918712249813, 0, 2.775555617144254] angle -1.0125378889468344
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.002565080420937, 0, 2.7848654277495375] angle -1.038689365338237
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.008378684210718, 0, 2.795053393673273] angle -1.0658088403215813
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.013455679371658, 0, 2.804541963026544] angle -1.0931757489679894
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.018140864858086, 0, 2.8138708881777594] angle -1.1175706679382749
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.022117794711222, 0, 2.8222225187870444] angle -1.13519080883492
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.025787520092932, 0, 2.830187215549381] angle -1.1428884755865858
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.02985850191777, 0, 2.8391233612357762] angle -1.1437623902464407
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.033984841533119, 0, 2.848044480309037] angle -1.131370451445254
# col_penalty: 0.0000
# Reward: -3.9879 --- Updated Reward: 0.4339
# col_penalty: 0.0000
# Reward: -4.1168 --- Updated Reward: 0.4449
# col_penalty: 0.0000
# Reward: -4.2362 --- Updated Reward: 0.4563
# col_penalty: 0.0000
# Reward: -4.3344 --- Updated Reward: 0.4673
# col_penalty: 0.0000
# Reward: -4.4085 --- Updated Reward: 0.4777
# col_penalty: 0.0000
# Reward: -4.4978 --- Updated Reward: 0.4888
# col_penalty: 0.0000
# Reward: -4.5771 --- Updated Reward: 0.4989
# col_penalty: 0.0000
# Reward: -4.6561 --- Updated Reward: 0.5087
# col_penalty: 0.0000
# Reward: -4.7225 --- Updated Reward: 0.5173
# col_penalty: 0.0000
# Reward: -4.8039 --- Updated Reward: 0.5254
# col_penalty: 0.0000
# Reward: -4.9027 --- Updated Reward: 0.5345
# 08:01:18|gym-duckietown|simulator.py:1435|_render_img(): Pos: [4.038462251288956, 0, 2.8573336090219126] angle -1.111925127786953
# 08:01:18|gym-duckietown|simulator.py:1107|_drivable_pos(): [4.09507326 0.         2.80259611] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.gym_duckietown.graphics.Texture object at 0x7f0ff8e54588>, 'color': array([1, 1, 1])}
# 08:01:18|gym-duckietown|simulator.py:1217|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 08:01:18|gym-duckietown|simulator.py:1218|_valid_pose(): safety_factor: 1.0
# 08:01:18|gym-duckietown|simulator.py:1219|_valid_pose(): pos: [4.02783178 0.         2.83581634]
# 08:01:18|gym-duckietown|simulator.py:1220|_valid_pose(): l_pos: [4.09507326 0.         2.80259611]
# 08:01:18|gym-duckietown|simulator.py:1221|_valid_pose(): r_pos: [3.9605903  0.         2.86903656]
# 08:01:18|gym-duckietown|simulator.py:1222|_valid_pose(): f_pos: [4.06769605 0.         2.91650611]
# 08:01:18|gym-duckietown|simulator.py:1376|_compute_done_reward(): Stopping the simulator because we are at an invalid pose.
# col_penalty: 0.0000
# Reward: -5.0081 --- Updated Reward: 0.5437
# col_penalty: 0.0000
# Reward: -1000.0000 --- Updated Reward: 0.5534

# %%
view_results_ipython(local_env)
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %%
print(local_env.cur_pos, local_env.cur_angle)
lp = local_env.get_lane_pos2(local_env.cur_pos, local_env.cur_angle)
print(lp)
print(local_env.proximity_penalty2(local_env.cur_pos, local_env.cur_angle))
# Out:
# [4.038462251288956, 0, 2.8573336090219126] -1.111925127786953
# LanePosition(dist=-0.5533891828846278, dot_dir=0.3318322128845906, angle_deg=-70.61997886041287, angle_rad=-1.2325511488029977)
# 0.0

# %% [markdown]
# **Question 0: After understanding the above computed reward, experiment with the constants for each component. What type of behavior does the above reward function penalize? Is this good or bad in context of autonomous driving? Name some other issues that can arise with single-objective optimization. In addition, give three sets of constants and explain qualitatively what types of behavior each penalizes or rewards (note, you may want to use a different action policy than random)**. Place the answers to the above in `reinforcement-learning-answers.txt`

# %% [markdown]
# # The Reinforcement Learning Learning Code
#
# Below we'll see a relatively naive implementation of the actor-critic training loop, which proceeds as follows: the critic is tasked with a supervised learning problem of fitting rewards acquired by the agent. Then, the policy, using policy gradients, maximizes the return according to the critic's estimate, rather than using Monte-Carlo updates.
#
# Below, we see an implementation of `DDPGAgent`, a class which handles the networks and training loop.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class DDPGAgent(object):
    def __init__(self, state_dim, action_dim, max_action=1.0):
        super(DDPGAgent, self).__init__()
        self.flat = False
        
        self.actor = Actor(action_dim, max_action).to(device)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=5e-2)
        
        self.critic = Critic(action_dim, max_action).to(device)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=5e-2)
        
        # MOD: Add 2 target networks
        self.actor_target = Actor(action_dim, max_action).to(device)
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.critic_target = Critic(action_dim, max_action).to(device)
        self.critic_target.load_state_dict(self.critic.state_dict())
        
        # MOD: Param for updating target networks
        self.tau = 0.001
        self.critic_losses = [] # To store critic loss
        self.actor_losses = [] # To store actor loss
        
    def predict(self, state):
        assert state.shape[0] == 3
        state = torch.FloatTensor(np.expand_dims(state, axis=0)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, iterations, batch_size=64, discount=0.99):
        for it in range(iterations):

            # Sample replay buffer
            sample = replay_buffer.sample(batch_size, flat=self.flat)
            state = torch.FloatTensor(sample["state"]).to(device)
            action = torch.FloatTensor(sample["action"]).to(device)
            next_state = torch.FloatTensor(sample["next_state"]).to(device)
            done = torch.FloatTensor(1 - sample["done"]).to(device)
            reward = torch.FloatTensor(sample["reward"]).to(device)

            # MOD: Compute the target Q value
            # target_Q = self.critic(next_state, self.actor(next_state))
            target_Q = self.critic_target(next_state, self.actor_target(next_state)) # Use target networks instead
            
            
            # TODO: - no detach is a subtle, but important bug!
            target_Q = (reward + (done * discount * target_Q)).detach()

            # Get current Q estimate
            current_Q = self.critic(state, action)

            # Compute critic loss
            critic_loss = F.mse_loss(current_Q, target_Q)

            # Optimize the critic
            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            self.critic_optimizer.step()

            # Compute actor loss
            actor_loss = -self.critic(state, self.actor(state)).mean()
    
            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()
            
            # MOD: store the losses
            self.critic_losses.append(critic_loss)
            self.actor_losses.append(actor_loss)
            
            # MOD: update actor_target and critic_target every iteration using soft update
            for real_param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * real_param.data + (1. - tau) * target_param.data)
            for real_param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * real_param.data + (1. - tau) * target_param.data)
                
    def save(self, filename, directory):
        torch.save(self.actor.state_dict(), '{}/{}_actor.pth'.format(directory, filename))
        torch.save(self.critic.state_dict(), '{}/{}_critic.pth'.format(directory, filename))

    def load(self, filename, directory):
        self.actor.load_state_dict(torch.load('{}/{}_actor.pth'.format(directory, filename), map_location=device))
        self.critic.load_state_dict(torch.load('{}/{}_critic.pth'.format(directory, filename), map_location=device))

# %% [markdown]
# You'll notice that the training loop needs a `replay_buffer` object. In value-based and actor-critic methods in deep reinforcement learning, the use of a replay buffer is crucial. In the following sections, you'll explore why this is the case, and some other stabilization techniques that are needed in order to get the above code to work. Below, you can find an implementation of the replay buffer, as well the training loop that we use to train DDPG.

# %%
# Simple replay buffer
class ReplayBuffer(object):
    def __init__(self, max_size=1e6):
        self.storage = []
        self.max_size = max_size

    # Expects tuples of (state, next_state, action, reward, done)
    def add(self, state, next_state, action, reward, done):
        if len(self.storage) < self.max_size:
            self.storage.append((state, next_state, action, reward, done))
        else:
            # Remove random element in the memory beforea adding a new one
            self.storage.pop(random.randrange(len(self.storage)))
            self.storage.append((state, next_state, action, reward, done))


    def sample(self, batch_size=100, flat=True):
        ind = np.random.randint(0, len(self.storage), size=batch_size)
        states, next_states, actions, rewards, dones = [], [], [], [], []

        for i in ind:
            state, next_state, action, reward, done = self.storage[i]

            if flat:
                states.append(np.array(state, copy=False).flatten())
                next_states.append(np.array(next_state, copy=False).flatten())
            else:
                states.append(np.array(state, copy=False))
                next_states.append(np.array(next_state, copy=False))
            actions.append(np.array(action, copy=False))
            rewards.append(np.array(reward, copy=False))
            dones.append(np.array(done, copy=False))

        # state_sample, action_sample, next_state_sample, reward_sample, done_sample
        return {
            "state": np.stack(states),
            "next_state": np.stack(next_states),
            "action": np.stack(actions),
            "reward": np.stack(rewards).reshape(-1,1),
            "done": np.stack(dones).reshape(-1,1)
        }

# %%
seed_ = 123
max_timesteps = 1e5  
batch_size = 64
discount = 0.99
eval_freq = 500 # 5e3
file_name = 'dt-class-rl'
start_timesteps = 1e3 # 1e3 # 1e4
expl_noise = 0.1
env_timesteps = 500 # 500 # this was not defined

# %%
import logging
logging.getLogger('gym-duckietown').disabled = True

# %%
local_env = launch_env()
# local_env = wrap_env(local_env)
local_env = ResizeWrapper(local_env)
local_env = ImgWrapper(local_env)

if not os.path.exists("./pytorch_models"):
    os.makedirs("./pytorch_models")

# Set seeds
seedall(seed_)

state_dim = local_env.observation_space.shape
action_dim = local_env.action_space.shape[0]
max_action = float(local_env.action_space.high[0])

# Initialize policy
policy = DDPGAgent(state_dim, action_dim, max_action)

replay_buffer = ReplayBuffer()

# Evaluate untrained policy
evaluations= [evaluate_policy(local_env, policy)]


# MOD: store reward and done flag
iter_rewards = []
episode_rewards = []
dones = []


total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
episode_reward = 0 # None
env_counter = 0
while total_timesteps < max_timesteps:
    if done:
        if total_timesteps != 0:
            print(("Total T: %d Episode Num: %d Episode T: %d Reward: %f") % (
                total_timesteps, episode_num, episode_timesteps, episode_reward))
            policy.train(replay_buffer, episode_timesteps, batch_size, discount)

        # Evaluate episode
        if timesteps_since_eval >= eval_freq:
            timesteps_since_eval %= eval_freq
            evaluations.append(evaluate_policy(local_env, policy))

            policy.save(file_name, directory="./pytorch_models")
            np.savez("./pytorch_models/{}.npz".format(file_name),evaluations)
        
        # MOD: log episode rewards
        episode_rewards.append(episode_reward)
        print('Episode: %d - Episode reward: %.4f' % (episode_num, episode_reward))
        
        # Reset environment
        env_counter += 1
        obs = local_env.reset()
        done = False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    # Select action randomly or according to policy
    if total_timesteps < start_timesteps:
        action = local_env.action_space.sample()
    else:
        action = policy.predict(np.array(obs))
        if expl_noise != 0:
            action = (action + np.random.normal(
                0,
                expl_noise,
                size=local_env.action_space.shape[0])
            ).clip(-1, +1)

    # Perform action
    new_obs, reward, done, _ = local_env.step(action)

    if episode_timesteps >= env_timesteps:
        done = True

    done_bool = 0 if episode_timesteps + 1 == env_timesteps else float(done)
    episode_reward += reward

    # Store data in replay buffer
    replay_buffer.add(obs, new_obs, action, reward, done_bool)

    obs = new_obs

    episode_timesteps += 1
    total_timesteps += 1
    timesteps_since_eval += 1
    
    # MOD: log reward and done flag
    dones.append(done)
    iter_rewards.append(reward)
    
    print('Iteration %d - episode: %d, reward: %.4f' % (total_timesteps, episode_num, reward))

# Final evaluation
evaluations.append(evaluate_policy(local_env, policy))

# if args.save_models:
policy.save(file_name, directory="./pytorch_models")
np.savez("./pytorch_models/{}.npz".format(file_name),evaluations)
# Out:
# action_dim:2
# action_dim:2
# Episode: 0 - Episode reward: 0.0000
# Iteration 1 - episode: 1, reward: -1.3040
# Iteration 2 - episode: 1, reward: -1.3040
# Iteration 3 - episode: 1, reward: -1.3040
# Iteration 4 - episode: 1, reward: -1.3040
# Iteration 5 - episode: 1, reward: -1.3039
# Iteration 6 - episode: 1, reward: -1.3035
# Iteration 7 - episode: 1, reward: -1.3033
# Iteration 8 - episode: 1, reward: -1.3044
# Iteration 9 - episode: 1, reward: -1.3073
# Iteration 10 - episode: 1, reward: -1.3124
# Iteration 11 - episode: 1, reward: -1.3231
# Iteration 12 - episode: 1, reward: -1.3409
# Iteration 13 - episode: 1, reward: -1.3588
# Iteration 14 - episode: 1, reward: -1.3705
# Iteration 15 - episode: 1, reward: -1.3924
# Iteration 16 - episode: 1, reward: -1.4084
# Iteration 17 - episode: 1, reward: -1.4188
# Iteration 18 - episode: 1, reward: -1.4188
# Iteration 19 - episode: 1, reward: -1.4173
# Iteration 20 - episode: 1, reward: -1.4146
# Iteration 21 - episode: 1, reward: -1.4097
# Iteration 22 - episode: 1, reward: -1.4108
# Iteration 23 - episode: 1, reward: -1.4110
# Iteration 24 - episode: 1, reward: -1.4154
# Iteration 25 - episode: 1, reward: -1.4241
# Iteration 26 - episode: 1, reward: -1.4398
# Iteration 27 - episode: 1, reward: -1.4620
# Iteration 28 - episode: 1, reward: -1.4700
# Iteration 29 - episode: 1, reward: -1.4740
# Iteration 30 - episode: 1, reward: -1.4785
# Iteration 31 - episode: 1, reward: -1.4722
# Iteration 32 - episode: 1, reward: -1.4572
# Iteration 33 - episode: 1, reward: -1.4496
# Iteration 34 - episode: 1, reward: -1.4499
# Iteration 35 - episode: 1, reward: -1.4536
# Iteration 36 - episode: 1, reward: -1.4639
# Iteration 37 - episode: 1, reward: -1.4795
# Iteration 38 - episode: 1, reward: -1.5027
# Iteration 39 - episode: 1, reward: -1.5320
# Iteration 40 - episode: 1, reward: -1.5727
# Iteration 41 - episode: 1, reward: -1.6209
# Iteration 42 - episode: 1, reward: -1.6623
# Iteration 43 - episode: 1, reward: -1.6907
# Iteration 44 - episode: 1, reward: -1.7009
# Iteration 45 - episode: 1, reward: -1.7058
# Iteration 46 - episode: 1, reward: -1.7175
# Iteration 47 - episode: 1, reward: -1.7339
# Iteration 48 - episode: 1, reward: -1.7651
# Iteration 49 - episode: 1, reward: -1.7829
# Iteration 50 - episode: 1, reward: -1.7934
# Iteration 51 - episode: 1, reward: -1.8032
# Iteration 52 - episode: 1, reward: -1.8189
# Iteration 53 - episode: 1, reward: -1.8436
# Iteration 54 - episode: 1, reward: -1.8604
# Iteration 55 - episode: 1, reward: -1.8888
# Iteration 56 - episode: 1, reward: -1.9047
# Iteration 57 - episode: 1, reward: -1.9210
# Iteration 58 - episode: 1, reward: -1.9374
# Iteration 59 - episode: 1, reward: -1.9612
# Iteration 60 - episode: 1, reward: -2.0043
# Iteration 61 - episode: 1, reward: -2.0373
# Iteration 62 - episode: 1, reward: -2.0610
# Iteration 63 - episode: 1, reward: -2.1030
# Iteration 64 - episode: 1, reward: -2.1254
# Iteration 65 - episode: 1, reward: -2.1448
# Iteration 66 - episode: 1, reward: -2.1881
# Iteration 67 - episode: 1, reward: -2.2062
# Iteration 68 - episode: 1, reward: -2.2259
# Iteration 69 - episode: 1, reward: -2.2465
# Iteration 70 - episode: 1, reward: -2.2416
# Iteration 71 - episode: 1, reward: -2.2585
# Iteration 72 - episode: 1, reward: -2.2567
# Iteration 73 - episode: 1, reward: -2.2603
# Iteration 74 - episode: 1, reward: -2.2464
# Iteration 75 - episode: 1, reward: -2.2366
# Iteration 76 - episode: 1, reward: -2.2508
# Iteration 77 - episode: 1, reward: -2.2924
# Iteration 78 - episode: 1, reward: -2.3399
# Iteration 79 - episode: 1, reward: -2.3587
# Iteration 80 - episode: 1, reward: -2.3495
# Iteration 81 - episode: 1, reward: -2.3476
# Iteration 82 - episode: 1, reward: -2.3541
# Iteration 83 - episode: 1, reward: -2.3549
# Iteration 84 - episode: 1, reward: -2.3274
# Iteration 85 - episode: 1, reward: -2.3173
# Iteration 86 - episode: 1, reward: -2.3266
# Iteration 87 - episode: 1, reward: -2.3262
# Iteration 88 - episode: 1, reward: -2.3542
# Iteration 89 - episode: 1, reward: -2.3616
# Iteration 90 - episode: 1, reward: -2.3918
# Iteration 91 - episode: 1, reward: -2.4029
# Iteration 92 - episode: 1, reward: -2.4316
# Iteration 93 - episode: 1, reward: -2.4598
# Iteration 94 - episode: 1, reward: -2.4526
# Iteration 95 - episode: 1, reward: -2.4264
# Iteration 96 - episode: 1, reward: -2.3841
# Iteration 97 - episode: 1, reward: -2.3819
# Iteration 98 - episode: 1, reward: -2.3695
# Iteration 99 - episode: 1, reward: -2.3722
# Iteration 100 - episode: 1, reward: -2.3550
# Iteration 101 - episode: 1, reward: -2.3392
# Iteration 102 - episode: 1, reward: -2.3160
# Iteration 103 - episode: 1, reward: -2.3312
# Iteration 104 - episode: 1, reward: -2.3346
# Iteration 105 - episode: 1, reward: -2.3525
# Iteration 106 - episode: 1, reward: -2.3390
# Iteration 107 - episode: 1, reward: -2.2920
# Iteration 108 - episode: 1, reward: -2.2274
# Iteration 109 - episode: 1, reward: -2.1843
# Iteration 110 - episode: 1, reward: -2.1406
# Iteration 111 - episode: 1, reward: -2.1201
# Iteration 112 - episode: 1, reward: -2.0804
# Iteration 113 - episode: 1, reward: -2.0385
# Iteration 114 - episode: 1, reward: -1.9946
# Iteration 115 - episode: 1, reward: -1.9715
# Iteration 116 - episode: 1, reward: -1.9750
# Iteration 117 - episode: 1, reward: -1.9841
# Iteration 118 - episode: 1, reward: -2.0017
# Iteration 119 - episode: 1, reward: -2.0150
# Iteration 120 - episode: 1, reward: -2.0405
# Iteration 121 - episode: 1, reward: -2.0563
# Iteration 122 - episode: 1, reward: -2.0662
# Iteration 123 - episode: 1, reward: -2.1014
# Iteration 124 - episode: 1, reward: -2.1432
# Iteration 125 - episode: 1, reward: -2.1810
# Iteration 126 - episode: 1, reward: -2.1955
# Iteration 127 - episode: 1, reward: -2.2109
# Iteration 128 - episode: 1, reward: -2.2388
# Iteration 129 - episode: 1, reward: -2.2738
# Iteration 130 - episode: 1, reward: -2.2908
# Iteration 131 - episode: 1, reward: -2.3030
# Iteration 132 - episode: 1, reward: -2.2791
# Iteration 133 - episode: 1, reward: -2.2630
# Iteration 134 - episode: 1, reward: -2.2378
# Iteration 135 - episode: 1, reward: -2.1839
# Iteration 136 - episode: 1, reward: -2.1361
# Iteration 137 - episode: 1, reward: -2.0757
# Iteration 138 - episode: 1, reward: -1.9929
# Iteration 139 - episode: 1, reward: -1.9115
# Iteration 140 - episode: 1, reward: -1.8142
# Iteration 141 - episode: 1, reward: -1.7181
# Iteration 142 - episode: 1, reward: -1.6374
# Iteration 143 - episode: 1, reward: -1.5892
# Iteration 144 - episode: 1, reward: -1.5545
# Iteration 145 - episode: 1, reward: -1.5444
# Iteration 146 - episode: 1, reward: -1.5407
# Iteration 147 - episode: 1, reward: -1.5475
# Iteration 148 - episode: 1, reward: -1.5823
# Iteration 149 - episode: 1, reward: -1.6466
# Iteration 150 - episode: 1, reward: -1.6971
# Iteration 151 - episode: 1, reward: -1.7195
# Iteration 152 - episode: 1, reward: -1.7196
# Iteration 153 - episode: 1, reward: -1.7273
# Iteration 154 - episode: 1, reward: -1.7627
# Iteration 155 - episode: 1, reward: -1.7835
# Iteration 156 - episode: 1, reward: -1.8363
# Iteration 157 - episode: 1, reward: -1.8794
# Iteration 158 - episode: 1, reward: -1.9268
# Iteration 159 - episode: 1, reward: -1.9347
# Iteration 160 - episode: 1, reward: -1.9424
# Iteration 161 - episode: 1, reward: -1.9204
# Iteration 162 - episode: 1, reward: -1.9170
# Iteration 163 - episode: 1, reward: -1.9119
# Iteration 164 - episode: 1, reward: -1.8784
# Iteration 165 - episode: 1, reward: -1.8370
# Iteration 166 - episode: 1, reward: -1.8290
# Iteration 167 - episode: 1, reward: -1.8393
# Iteration 168 - episode: 1, reward: -1.8806
# Iteration 169 - episode: 1, reward: -1.9397
# Iteration 170 - episode: 1, reward: -1.9549
# Iteration 171 - episode: 1, reward: -1.9491
# Iteration 172 - episode: 1, reward: -1.9217
# Iteration 173 - episode: 1, reward: -1.9130
# Iteration 174 - episode: 1, reward: -1.8768
# Iteration 175 - episode: 1, reward: -1.8445
# Iteration 176 - episode: 1, reward: -1.8144
# Iteration 177 - episode: 1, reward: -1.7937
# Iteration 178 - episode: 1, reward: -1.7933
# Iteration 179 - episode: 1, reward: -1.7624
# Iteration 180 - episode: 1, reward: -1.7410
# Iteration 181 - episode: 1, reward: -1.6957
# Iteration 182 - episode: 1, reward: -1.6588
# Iteration 183 - episode: 1, reward: -1.6115
# Iteration 184 - episode: 1, reward: -1.5732
# Iteration 185 - episode: 1, reward: -1.5694
# Iteration 186 - episode: 1, reward: -1.5905
# Iteration 187 - episode: 1, reward: -1.6392
# Iteration 188 - episode: 1, reward: -1.6715
# Iteration 189 - episode: 1, reward: -1.7134
# Iteration 190 - episode: 1, reward: -1.7728
# Iteration 191 - episode: 1, reward: -1.8528
# Iteration 192 - episode: 1, reward: -1.9537
# Iteration 193 - episode: 1, reward: -2.0248
# Iteration 194 - episode: 1, reward: -2.0556
# Iteration 195 - episode: 1, reward: -2.0573
# Iteration 196 - episode: 1, reward: -2.0716
# Iteration 197 - episode: 1, reward: -2.0824
# Iteration 198 - episode: 1, reward: -2.0758
# Iteration 199 - episode: 1, reward: -2.0530
# Iteration 200 - episode: 1, reward: -2.0009
# Iteration 201 - episode: 1, reward: -1.9690
# Iteration 202 - episode: 1, reward: -1.9548
# Iteration 203 - episode: 1, reward: -1.9703
# Iteration 204 - episode: 1, reward: -1.9561
# Iteration 205 - episode: 1, reward: -1.9715
# Iteration 206 - episode: 1, reward: -1.9774
# Iteration 207 - episode: 1, reward: -1.9509
# Iteration 208 - episode: 1, reward: -1.9292
# Iteration 209 - episode: 1, reward: -1.9231
# Iteration 210 - episode: 1, reward: -1.9380
# Iteration 211 - episode: 1, reward: -1.9220
# Iteration 212 - episode: 1, reward: -1.8827
# Iteration 213 - episode: 1, reward: -1.8741
# Iteration 214 - episode: 1, reward: -1.8470
# Iteration 215 - episode: 1, reward: -1.8035
# Iteration 216 - episode: 1, reward: -1.7421
# Iteration 217 - episode: 1, reward: -1.6822
# Iteration 218 - episode: 1, reward: -1.6603
# Iteration 219 - episode: 1, reward: -1.6295
# Iteration 220 - episode: 1, reward: -1.5835
# Iteration 221 - episode: 1, reward: -1.5348
# Iteration 222 - episode: 1, reward: -1.4970
# Iteration 223 - episode: 1, reward: -1.4514
# Iteration 224 - episode: 1, reward: -1.4328
# Iteration 225 - episode: 1, reward: -1.4154
# Iteration 226 - episode: 1, reward: -1.3794
# Iteration 227 - episode: 1, reward: -1.3478
# Iteration 228 - episode: 1, reward: -1.3255
# Iteration 229 - episode: 1, reward: -1.3052
# Iteration 230 - episode: 1, reward: -1.2792
# Iteration 231 - episode: 1, reward: -1.2283
# Iteration 232 - episode: 1, reward: -1.2142
# Iteration 233 - episode: 1, reward: -1.1935
# Iteration 234 - episode: 1, reward: -1.1983
# Iteration 235 - episode: 1, reward: -1.2044
# Iteration 236 - episode: 1, reward: -1.2107
# Iteration 237 - episode: 1, reward: -1.2367
# Iteration 238 - episode: 1, reward: -1.2291
# Iteration 239 - episode: 1, reward: -1.1981
# Iteration 240 - episode: 1, reward: -1.1786
# Iteration 241 - episode: 1, reward: -1.1360
# Iteration 242 - episode: 1, reward: -1.1255
# Iteration 243 - episode: 1, reward: -1.1218
# Iteration 244 - episode: 1, reward: -1.1506
# Iteration 245 - episode: 1, reward: -1.2070
# Iteration 246 - episode: 1, reward: -1.2269
# Iteration 247 - episode: 1, reward: -1.2316
# Iteration 248 - episode: 1, reward: -1.2155
# Iteration 249 - episode: 1, reward: -1.2411
# Iteration 250 - episode: 1, reward: -1.2410
# Iteration 251 - episode: 1, reward: -1.2766
# Iteration 252 - episode: 1, reward: -1.2833
# Iteration 253 - episode: 1, reward: -1.0573
# Iteration 254 - episode: 1, reward: -1.0363
# Iteration 255 - episode: 1, reward: -1.3156
# Iteration 256 - episode: 1, reward: -1.0200
# Iteration 257 - episode: 1, reward: -1.2974
# Iteration 258 - episode: 1, reward: -1.0483
# Iteration 259 - episode: 1, reward: -1.0380
# Iteration 260 - episode: 1, reward: -1.0038
# Iteration 261 - episode: 1, reward: -1.0005
# Iteration 262 - episode: 1, reward: -0.9900
# Iteration 263 - episode: 1, reward: -0.9816
# Iteration 264 - episode: 1, reward: -0.9440
# Iteration 265 - episode: 1, reward: -0.9337
# Iteration 266 - episode: 1, reward: -0.9329
# Iteration 267 - episode: 1, reward: -0.9046
# Iteration 268 - episode: 1, reward: -0.8812
# Iteration 269 - episode: 1, reward: -0.8797
# Iteration 270 - episode: 1, reward: -0.8923
# Iteration 271 - episode: 1, reward: -0.9344
# Iteration 272 - episode: 1, reward: -0.9559
# Iteration 273 - episode: 1, reward: -0.9983
# Iteration 274 - episode: 1, reward: -1.0290
# Iteration 275 - episode: 1, reward: -1.0363
# Iteration 276 - episode: 1, reward: -1.2712
# Iteration 277 - episode: 1, reward: -1.2104
# Iteration 278 - episode: 1, reward: -1.1914
# Iteration 279 - episode: 1, reward: -1.1478
# Iteration 280 - episode: 1, reward: -1.0899
# Iteration 281 - episode: 1, reward: -1.0316
# Iteration 282 - episode: 1, reward: -0.9917
# Iteration 283 - episode: 1, reward: -0.9296
# Iteration 284 - episode: 1, reward: -0.8783
# Iteration 285 - episode: 1, reward: -0.8091
# Iteration 286 - episode: 1, reward: -0.7629
# Iteration 287 - episode: 1, reward: -0.7153
# Iteration 288 - episode: 1, reward: -0.6508
# Iteration 289 - episode: 1, reward: -0.5696
# Iteration 290 - episode: 1, reward: -0.5090
# Iteration 291 - episode: 1, reward: -0.4386
# Iteration 292 - episode: 1, reward: -0.3575
# Iteration 293 - episode: 1, reward: -0.3150
# Iteration 294 - episode: 1, reward: -0.2901
# Iteration 295 - episode: 1, reward: -0.2832
# Iteration 296 - episode: 1, reward: -0.2744
# Iteration 297 - episode: 1, reward: -0.2833
# Iteration 298 - episode: 1, reward: -0.2668
# Iteration 299 - episode: 1, reward: -0.2340
# Iteration 300 - episode: 1, reward: -0.1999
# Iteration 301 - episode: 1, reward: -0.1645
# Iteration 302 - episode: 1, reward: -0.1402
# Iteration 303 - episode: 1, reward: -0.1302
# Iteration 304 - episode: 1, reward: -0.1114
# Iteration 305 - episode: 1, reward: -0.0999
# Iteration 306 - episode: 1, reward: -0.0888
# Iteration 307 - episode: 1, reward: -0.0705
# Iteration 308 - episode: 1, reward: -0.0586
# Iteration 309 - episode: 1, reward: -0.0531
# Iteration 310 - episode: 1, reward: -0.0531
# Iteration 311 - episode: 1, reward: -0.0502
# Iteration 312 - episode: 1, reward: -0.0507
# Iteration 313 - episode: 1, reward: -0.0505
# Iteration 314 - episode: 1, reward: -0.0502
# Iteration 315 - episode: 1, reward: -0.0504
# Iteration 316 - episode: 1, reward: -0.0494
# Iteration 317 - episode: 1, reward: -0.0477
# Iteration 318 - episode: 1, reward: -0.0454
# Iteration 319 - episode: 1, reward: -0.0445
# Iteration 320 - episode: 1, reward: -0.0441
# Iteration 321 - episode: 1, reward: -0.0457
# Iteration 322 - episode: 1, reward: -0.0441
# Iteration 323 - episode: 1, reward: -0.0442
# Iteration 324 - episode: 1, reward: -0.0446
# Iteration 325 - episode: 1, reward: -0.0448
# Iteration 326 - episode: 1, reward: -0.0445
# Iteration 327 - episode: 1, reward: -0.0446
# Iteration 328 - episode: 1, reward: -0.0454
# Iteration 329 - episode: 1, reward: -0.0472
# Iteration 330 - episode: 1, reward: -0.0455
# Iteration 331 - episode: 1, reward: -0.0415
# Iteration 332 - episode: 1, reward: -0.0390
# Iteration 333 - episode: 1, reward: -0.0395
# Iteration 334 - episode: 1, reward: -0.0413
# Iteration 335 - episode: 1, reward: -0.0391
# Iteration 336 - episode: 1, reward: -0.0403
# Iteration 337 - episode: 1, reward: -0.0387
# Iteration 338 - episode: 1, reward: -0.0344
# Iteration 339 - episode: 1, reward: -0.0326
# Iteration 340 - episode: 1, reward: -0.0260
# Iteration 341 - episode: 1, reward: -0.0165
# Iteration 342 - episode: 1, reward: -0.0027
# Iteration 343 - episode: 1, reward: 0.0019
# Iteration 344 - episode: 1, reward: 0.0117
# Iteration 345 - episode: 1, reward: 0.0259
# Iteration 346 - episode: 1, reward: 0.0368
# Iteration 347 - episode: 1, reward: 0.0405
# Iteration 348 - episode: 1, reward: 0.0330
# Iteration 349 - episode: 1, reward: 0.0224
# Iteration 350 - episode: 1, reward: 0.0038
# Iteration 351 - episode: 1, reward: -0.0271
# Iteration 352 - episode: 1, reward: -0.0420
# Iteration 353 - episode: 1, reward: -0.0494
# Iteration 354 - episode: 1, reward: -0.0472
# Iteration 355 - episode: 1, reward: -0.0587
# Iteration 356 - episode: 1, reward: -0.0487
# Iteration 357 - episode: 1, reward: -0.0621
# Iteration 358 - episode: 1, reward: -0.0803
# Iteration 359 - episode: 1, reward: -0.0796
# Iteration 360 - episode: 1, reward: -0.0830
# Iteration 361 - episode: 1, reward: -0.0672
# Iteration 362 - episode: 1, reward: -0.0587
# Iteration 363 - episode: 1, reward: -0.0352
# Iteration 364 - episode: 1, reward: -0.0349
# Iteration 365 - episode: 1, reward: -0.0396
# Iteration 366 - episode: 1, reward: -0.0671
# Iteration 367 - episode: 1, reward: -0.0656
# Iteration 368 - episode: 1, reward: -0.0747
# Iteration 369 - episode: 1, reward: -0.1008
# Iteration 370 - episode: 1, reward: -0.1404
# Iteration 371 - episode: 1, reward: -0.1682
# Iteration 372 - episode: 1, reward: -0.1749
# Iteration 373 - episode: 1, reward: -0.1993
# Iteration 374 - episode: 1, reward: -0.1926
# Iteration 375 - episode: 1, reward: -0.1693
# Iteration 376 - episode: 1, reward: -0.1322
# Iteration 377 - episode: 1, reward: -0.1178
# Iteration 378 - episode: 1, reward: -0.0858
# Iteration 379 - episode: 1, reward: -0.0601
# Iteration 380 - episode: 1, reward: -0.0212
# Iteration 381 - episode: 1, reward: 0.0168
# Iteration 382 - episode: 1, reward: 0.0445
# Iteration 383 - episode: 1, reward: 0.0659
# Iteration 384 - episode: 1, reward: 0.0779
# Iteration 385 - episode: 1, reward: 0.0898
# Iteration 386 - episode: 1, reward: 0.0947
# Iteration 387 - episode: 1, reward: 0.0961
# Iteration 388 - episode: 1, reward: 0.0974
# Iteration 389 - episode: 1, reward: 0.0974
# Iteration 390 - episode: 1, reward: 0.0974
# Iteration 391 - episode: 1, reward: 0.0973
# Iteration 392 - episode: 1, reward: 0.0975
# Iteration 393 - episode: 1, reward: 0.0981
# Iteration 394 - episode: 1, reward: 0.0994
# Iteration 395 - episode: 1, reward: 0.1016
# Iteration 396 - episode: 1, reward: 0.1031
# Iteration 397 - episode: 1, reward: 0.1024
# Iteration 398 - episode: 1, reward: 0.1040
# Iteration 399 - episode: 1, reward: 0.1072
# Iteration 400 - episode: 1, reward: 0.1079
# Iteration 401 - episode: 1, reward: 0.1092
# Iteration 402 - episode: 1, reward: 0.1110
# Iteration 403 - episode: 1, reward: 0.1111
# Iteration 404 - episode: 1, reward: 0.1110
# Iteration 405 - episode: 1, reward: 0.1101
# Iteration 406 - episode: 1, reward: 0.1080
# Iteration 407 - episode: 1, reward: 0.1072
# Iteration 408 - episode: 1, reward: 0.1042
# Iteration 409 - episode: 1, reward: 0.1017
# Iteration 410 - episode: 1, reward: 0.0973
# Iteration 411 - episode: 1, reward: 0.0968
# Iteration 412 - episode: 1, reward: 0.1006
# Iteration 413 - episode: 1, reward: 0.1048
# Iteration 414 - episode: 1, reward: 0.1110
# Iteration 415 - episode: 1, reward: 0.1127
# Iteration 416 - episode: 1, reward: 0.1132
# Iteration 417 - episode: 1, reward: 0.1138
# Iteration 418 - episode: 1, reward: 0.1136
# Iteration 419 - episode: 1, reward: 0.1117
# Iteration 420 - episode: 1, reward: 0.1054
# Iteration 421 - episode: 1, reward: 0.0944
# Iteration 422 - episode: 1, reward: 0.0822
# Iteration 423 - episode: 1, reward: 0.0595
# Iteration 424 - episode: 1, reward: 0.0240
# Iteration 425 - episode: 1, reward: -0.0008
# Iteration 426 - episode: 1, reward: -0.0380
# Iteration 427 - episode: 1, reward: -0.0770
# Iteration 428 - episode: 1, reward: -0.1232
# Iteration 429 - episode: 1, reward: -0.1806
# Iteration 430 - episode: 1, reward: -0.2144
# Iteration 431 - episode: 1, reward: -0.2543
# Iteration 432 - episode: 1, reward: -0.3039
# Iteration 433 - episode: 1, reward: -0.3379
# Iteration 434 - episode: 1, reward: -0.3439
# Iteration 435 - episode: 1, reward: -0.3574
# Iteration 436 - episode: 1, reward: -0.3868
# Iteration 437 - episode: 1, reward: -0.4000
# Iteration 438 - episode: 1, reward: -0.3922
# Iteration 439 - episode: 1, reward: -0.3849
# Iteration 440 - episode: 1, reward: -0.3741
# Iteration 441 - episode: 1, reward: -0.3858
# Iteration 442 - episode: 1, reward: -0.4165
# Iteration 443 - episode: 1, reward: -0.4662
# Iteration 444 - episode: 1, reward: -0.5204
# Iteration 445 - episode: 1, reward: -0.5350
# Iteration 446 - episode: 1, reward: -0.5449
# Iteration 447 - episode: 1, reward: -0.5697
# Iteration 448 - episode: 1, reward: -0.6044
# Iteration 449 - episode: 1, reward: -0.6573
# Iteration 450 - episode: 1, reward: -0.7335
# Iteration 451 - episode: 1, reward: -0.8056
# Iteration 452 - episode: 1, reward: -0.8467
# Iteration 453 - episode: 1, reward: -0.8972
# Iteration 454 - episode: 1, reward: -0.9518
# Iteration 455 - episode: 1, reward: -1.0075
# Iteration 456 - episode: 1, reward: -1.0598
# Iteration 457 - episode: 1, reward: -1.0799
# Iteration 458 - episode: 1, reward: -1.0815
# Iteration 459 - episode: 1, reward: -1.0903
# Iteration 460 - episode: 1, reward: -1.0734
# Iteration 461 - episode: 1, reward: -1.0409
# Iteration 462 - episode: 1, reward: -1.0173
# Iteration 463 - episode: 1, reward: -0.9779
# Iteration 464 - episode: 1, reward: -0.9608
# Iteration 465 - episode: 1, reward: -0.9475
# Iteration 466 - episode: 1, reward: -0.9252
# Iteration 467 - episode: 1, reward: -0.9210
# Iteration 468 - episode: 1, reward: -0.9011
# Iteration 469 - episode: 1, reward: -0.8669
# Iteration 470 - episode: 1, reward: -0.8354
# Iteration 471 - episode: 1, reward: -0.8174
# Iteration 472 - episode: 1, reward: -0.7732
# Iteration 473 - episode: 1, reward: -0.7131
# Iteration 474 - episode: 1, reward: -0.6683
# Iteration 475 - episode: 1, reward: -0.6149
# Iteration 476 - episode: 1, reward: -0.5475
# Iteration 477 - episode: 1, reward: -0.5013
# Iteration 478 - episode: 1, reward: -0.4885
# Iteration 479 - episode: 1, reward: -0.4977
# Iteration 480 - episode: 1, reward: -0.5238
# Iteration 481 - episode: 1, reward: -0.5675
# Iteration 482 - episode: 1, reward: -0.5847
# Iteration 483 - episode: 1, reward: -0.6286
# Iteration 484 - episode: 1, reward: -0.6679
# Iteration 485 - episode: 1, reward: -0.6867
# Iteration 486 - episode: 1, reward: -0.6856
# Iteration 487 - episode: 1, reward: -0.7109
# Iteration 488 - episode: 1, reward: -0.7683
# Iteration 489 - episode: 1, reward: -0.8489
# Iteration 490 - episode: 1, reward: -0.9023
# Iteration 491 - episode: 1, reward: -0.9645
# Iteration 492 - episode: 1, reward: -1.0367
# Iteration 493 - episode: 1, reward: -1.2097
# Iteration 494 - episode: 1, reward: -1.1464
# Iteration 495 - episode: 1, reward: -1.0899
# Iteration 496 - episode: 1, reward: -1.0426
# Iteration 497 - episode: 1, reward: -1.0276
# Iteration 498 - episode: 1, reward: -1.0420
# Iteration 499 - episode: 1, reward: -1.0204
# Iteration 500 - episode: 1, reward: -1.0248
# Iteration 501 - episode: 1, reward: -1.0443
# Total T: 501 Episode Num: 1 Episode T: 501 Reward: -550.278960
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-e2c05bec088b> in <module>
#      40             print(("Total T: %d Episode Num: %d Episode T: %d Reward: %f") % (
#      41                 total_timesteps, episode_num, episode_timesteps, episode_reward))
# ---> 42             policy.train(replay_buffer, episode_timesteps, batch_size, discount)
#      43
#      44         # Evaluate episode
#
# <ipython-input-35-8ee71b3c9e8c> in train(self, replay_buffer, iterations, batch_size, discount)
#      62             # Optimize the actor
#      63             self.actor_optimizer.zero_grad()
# ---> 64             actor_loss.backward()
#      65             self.actor_optimizer.step()
#      66
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %% [markdown]
# # Stabilizing DDPG
#
# As you may notice, the above model performs poorly or doesn't converge. Your job is to improve it; first in the notebook, later in the AIDO submission. This last part of the assignment consists of four sections:
#
# **1. There are subtle, but important, bugs that have been introduced into the code above. Your job is to find them, and explain them in your `reinforcement-learning-answers.txt`. You'll want to reread the original [DQN](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning) and [DDPG](https://arxiv.org/abs/1509.02971) papers in order to better understand the issue, but by answering the following subquestions (*please put the answers to these in the submission for full credit*), you'll be on the right track:**
#
#    a) Read some literature on actor-critic methods, including the original [actor-critic](https://papers.nips.cc/paper/1786-actor-critic-algorithms.pdf) paper. What is an issue that you see related to *non-stationarity*? Define what _non-stationarity_ means in the context of machine learning and how it relates to actor-critic methods. In addition, give some hypotheses on why reinforcement learning is much more difficult (from an optimization perspective) than supervised learning, and how the answer to the previous question and this one are related.
#
#    b) What role does the replay buffer play in off-policy reinforcement learning? It's most important parameter is `max_size` - how does changing this value (answer for both increasing and decreasing trends) qualitatively affect the training of the algorithm?
#
#    c) **Challenge Question:** Briefly, explain how automatic differentiation works. In addition, expand on the difference between a single-element tensor (that `requires_grad`) and a scalar value as it relates to automatic differentiation; when do we want to backpropogate through a single-element tensor, and when do we not? Take a close look at the code and how losses are being backpropogated. On paper or your favorite drawing software, draw out the actor-critic architecture *as described in the code*, and label how the actor and critic losses are backpropogated. On your diagram, highlight the particular loss that will cause issues with the above code, and fix it.
#
# For the next section, please pick **either** the theoretical or the practical pathway. If you don't have access to the necessary compute, for the exercise, please do the theoretical portion.
#
# _Theoretical Component_
#
# **2. We discussed a case study of DQN in class. The original authors used quite a few tricks to get this to work. Detail some of the following, and explain what problem they solve in training the DQN:**
#
# a) Target Networks
#
# b) Annealed Learning Rates
#
# c) Replay Buffer
#
# d) Random Exploration Period
#
# e) Preprocessing the Image
#
#
# **3. Read about either [TD3](https://arxiv.org/abs/1802.09477) or [Soft Actor Critic](https://arxiv.org/abs/1801.01290); for your choice, summarize what problems they are addressing with the standard actor-critic formulation, and how they solve them**
#
#
# _Practical Component_
#
# **2. [Optional - if you have access to compute] Using your analysis from the reward engineering ablation, train two agents (after you've found the bugs in DDPG) - one with the standard, `gym-duckietown` reward, and another with the parameters of your choosing. Report each set of parameters, and describe qualitatively what type of behavior the agent produces.**
#
# If you don't have the resources to actually train these agents, instead describe what types of behaviors each reward function might prioritize.
#
# **3. [Optional - if you have access to compute] Using the instructions [here](http://docs.duckietown.org/DT19/AIDO/out/embodied_rl.html), use the saved policy files from this notebook and submit using the template submission provided through the AIDO submission. Report your best submission number (i.e the one you'd like to be graded) in `reinforcement-learning-answers.txt`**
